# %%
import cv2
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/mahdizangeneh/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolo8n.pt') # by default it's DETECTION

# Assuming 'crowded.jog' is in the same directory
result = model('crowded.jog', show=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 from ultralytics import YOLO
#       2 import cv2
# ----> 4 model = YOLO('yolo8n.pt') # by default it's DETECTION
#       6 # Assuming 'crowded.jog' is in the same directory
#       7 result = model('crowded.jog', show=True)
#
# File ~/Documents/aSeneca/aSemester-7/CVI/virtualEnvPractice/lib/python3.10/site-packages/ultralytics/models/yolo/model.py:54, in YOLO.__init__(self, model, task, verbose)
#      51     self.__dict__ = new_instance.__dict__
#      52 else:
#      53     # Continue with default YOLO initialization
# ---> 54     super().__init__(model=model, task=task, verbose=verbose)
#
# File ~/Documents/aSeneca/aSemester-7/CVI/virtualEnvPractice/lib/python3.10/site-packages/ultralytics/engine/model.py:148, in Model.__init__(self, model, task, verbose)
# ...
