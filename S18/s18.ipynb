# %% [markdown]
# ### Supervised machine learning:
# Classification: classify our data  (descrete) KNN , LOR (logistic regression)
# Regression: predict something  (continious)  Simple Linear regression (SLR) , MLR (multiple linear regression)  , LR-SGD

# %% [markdown]
# ### Logistic Regression
# classifying linearly
# NOTE: We have to test which algorithm we want to pick (KNN or LOR)

# %% [markdown]
# ##### The core objective of both classification and regression algorithms is to minimize their respective loss functions.
# That the loss function is the metric that the models use to learn from the data.
# That gradient descent is the tool to optimize the loss function
