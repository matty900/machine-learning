# %% [markdown]
# Scikit-learn (sklearn): For traditional machine learning, it excels in tasks like:
# * Classification (e.g., spam detection)
# * Regression (e.g., predicting house prices)
# * Clustering (e.g., customer segmentation)
#
# TensorFlow and PyTorch: Deep learning frameworks They are designed for building and training neural networks.  (deep leanring, neural networks)
# TensorFlow (Google) -> with Keras (extra layer) together , Pytorch (Meta)
# * Image recognition
# * Natural language processing
# * Other complex pattern recognition problems.

# %% [markdown]
# CNN (Convolutional Neural Networks)
# Deep Learning 2012
#
# Convolution on images => edge kernel -> 1. try and test 2. Ml (using GD)
#
# Layers in CNN:
# Convolutional
# Pooling
# Fully Connected
# Activation function
# Batch Normalization  (Not covered)
